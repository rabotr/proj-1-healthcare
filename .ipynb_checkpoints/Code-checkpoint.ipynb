# %% [markdown]
# # RESOURCES
#
# HCAPS hospital survey: https://data.medicare.gov/Hospital-Compare/Patient-survey-HCAHPS-Hospital/dgck-syfz
#
# population data: https://www.census.gov/data/tables/2016/demo/popest/total-cities-and-towns.html#par_textimage
#
# CDC API info: https://wonder.cdc.gov/wonder/help/WONDER-API.html

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import collections

# %%
# Import patient survey data into pandas from CSV
survey_raw_df = pd.read_csv('Resources/Patient_survey__HCAHPS__-_Hospital.csv')

print(f'Total number of unique hospitals: {survey_raw_df["Hospital Name"].nunique()}')
survey_raw_df.head()
# Out:
# Total number of unique hospitals: 4613
#    Provider ID                         Hospital Name  \
# 0       240018  MAYO CLINIC HEALTH SYSTEM - RED WING
# 1       231334            PROMEDICA HERRICK HOSPITAL
# 2       231332             BRONSON LAKEVIEW HOSPITAL
# 3       240010        MAYO CLINIC HOSPITAL ROCHESTER
# 4       231330            MARLETTE REGIONAL HOSPITAL
#
#                            Address       City State  ZIP Code County Name  \
# 0  701 HEWITT BOULEVARD, PO BOX 95   RED WING    MN     55066     GOODHUE
# 1        500 E POTTAWATAMIE STREET   TECUMSEH    MI     49286     LENAWEE
# 2                 408 HAZEN STREET    PAW PAW    MI     49079   VAN BUREN
# 3     1216 SECOND STREET SOUTHWEST  ROCHESTER    MN     55902     OLMSTED
# 4                 2770 MAIN STREET   MARLETTE    MI     48453     SANILAC
#
#    Phone Number      HCAHPS Measure ID  \
# 0    6512675000  H_COMP_3_LINEAR_SCORE
# 1    5174243000       H_QUIET_HSP_SN_P
# 2    2696571400           H_COMP_1_A_P
# 3    5072555123            H_RECMND_PY
# 4    9896354000  H_COMP_5_LINEAR_SCORE
#
#                                      HCAHPS Question  \
# 0           Staff responsiveness - linear mean score
# 1  Patients who reported that the area around the...
# 2  Patients who reported that their nurses "Alway...
# 3  Patients who reported YES, they would probably...
# 4  Communication about medicines - linear mean score
#
#                          ...                         HCAHPS Answer Percent  \
# 0                        ...                                Not Applicable
# 1                        ...                                 Not Available
# 2                        ...                                            85
# 3                        ...                                            15
# 4                        ...                                Not Applicable
#
#                       HCAHPS Answer Percent Footnote HCAHPS Linear Mean Value  \
# 0                                                NaN                       93
# 1  1 - The number of cases/patients is too few to...           Not Applicable
# 2  11 - There were discrepancies in the data coll...           Not Applicable
# 3                                                NaN           Not Applicable
# 4                                                NaN                       76
#
#   Number of Completed Surveys  \
# 0                         347
# 1               Not Available
# 2                         130
# 3                         708
# 4                         119
#
#                 Number of Completed Surveys Footnote  \
# 0                                                NaN
# 1  1 - The number of cases/patients is too few to...
# 2  11 - There were discrepancies in the data coll...
# 3                                                NaN
# 4                                                NaN
#
#   Survey Response Rate Percent  \
# 0                           33
# 1                Not Available
# 2                           30
# 3                           38
# 4                           38
#
#                Survey Response Rate Percent Footnote Measure Start Date  \
# 0                                                NaN         07/01/2016
# 1  1 - The number of cases/patients is too few to...         07/01/2016
# 2  11 - There were discrepancies in the data coll...         07/01/2016
# 3                                                NaN         07/01/2016
# 4                                                NaN         07/01/2016
#
#   Measure End Date                                           Location
# 0       06/30/2017  701 HEWITT BOULEVARD, PO BOX 95\nRED WING, MN\...
# 1       06/30/2017  500 E POTTAWATAMIE STREET\nTECUMSEH, MI\n(42.0...
# 2       06/30/2017  408 HAZEN STREET\nPAW PAW, MI\n(42.221009, -85...
# 3       06/30/2017  1216 SECOND STREET SOUTHWEST\nROCHESTER, MN\n(...
# 4       06/30/2017  2770 MAIN STREET\nMARLETTE, MI\n(43.332579, -8...
#
# [5 rows x 23 columns]

# %%
# Only include survey columns with "State", "City", "Hospital Name", 
# "Patient Survey Star Rating", "Number of Completed Surveys", "Survey Response Rate Percent", "Location"
# create ordered dict to hold values
hospital_dict = collections.OrderedDict([("State", []),
                                    ("County", []),
                                    ("City", []),
                                    ("Hospital", []),
                                    ("Location", []),
                                    ("Patient Rating", []),
                                    ("Completed Surveys", []),
                                    ("Survey Response Rate (%)", [])])


# Only include survey rows with hospital "HCAHPS Measure ID" == "H_STAR_RATING"
for index, hospital in survey_raw_df.iterrows():
    if (hospital["HCAHPS Measure ID"] == "H_STAR_RATING") and (hospital["Patient Survey Star Rating"] != "Not Available"):
        hospital_dict["State"].append(hospital["State"])
        hospital_dict["County"].append(hospital["County Name"])
        hospital_dict["City"].append(hospital["City"])
        hospital_dict["Hospital"].append(hospital["Hospital Name"])
        hospital_dict["Location"].append(hospital["Location"])
        hospital_dict["Patient Rating"].append(hospital["Patient Survey Star Rating"])
        hospital_dict["Completed Surveys"].append(hospital["Number of Completed Surveys"])
        hospital_dict["Survey Response Rate (%)"].append(hospital["Survey Response Rate Percent"])

# make dataframe                      
hospital_df = pd.DataFrame(hospital_dict)

# print dataframe
hospital_df.head()
# Out:
#   State       County         City                                  Hospital  \
# 0    MN     HENNEPIN  ROBBINSDALE             NORTH MEMORIAL MEDICAL CENTER
# 1    AL     MARSHALL         BOAZ             MARSHALL MEDICAL CENTER SOUTH
# 2    MN      OLMSTED    ROCHESTER            MAYO CLINIC HOSPITAL ROCHESTER
# 3    MN      GOODHUE     RED WING      MAYO CLINIC HEALTH SYSTEM - RED WING
# 4    MN  SAINT LOUIS       DULUTH  ESSENTIA HEALTH ST MARY'S MEDICAL CENTER
#
#                                             Location Patient Rating  \
# 0  3300 OAKDALE NORTH\nROBBINSDALE, MN\n(45.01421...              3
# 1             2505 U S HIGHWAY 431 NORTH\nBOAZ, AL\n              3
# 2  1216 SECOND STREET SOUTHWEST\nROCHESTER, MN\n(...              4
# 3  701 HEWITT BOULEVARD, PO BOX 95\nRED WING, MN\...              4
# 4  407 EAST THIRD STREET\nDULUTH, MN\n(46.792843,...              3
#
#   Completed Surveys Survey Response Rate (%)
# 0               957                       26
# 1              1250                       35
# 2               708                       38
# 3               347                       33
# 4              1816                       31

# %%
print(f"Total # of hospitals with star ratings: {data_df.Hospital.count()}")

# export df to csv
hospital_df.to_csv('Resources/hospital_cleaned_data.csv')
# Out:
# Total # of hospitals with star ratings: 3470

# %%
# Import mortality data (with population data)
mortality_df = pd.read_csv('Resources/mortality_2016_final.csv')

mortality_df.head()
# Out:
#    Unnamed: 0 State    County Deaths Population Crude Rate Age Adjusted Rate  \
# 0           0    AL  AUTAUGA     520      55416     938.36            884.39
# 1           1    AL  BALDWIN    1974     208563     946.48            716.92
# 2           2    AL  BARBOUR     256      25965     985.94            800.68
# 3           3    AL     BIBB     239      22643    1055.51            927.67
# 4           4    AL   BLOUNT     697      57704    1207.89            989.37
#
#   % of Total Deaths
# 0             0.02%
# 1             0.07%
# 2             0.01%
# 3             0.01%
# 4             0.03%

# %%
# merge df on state and county
data_df = pd.merge(hospital_df, mortality_df, how="outer", on=["State", "County"])

# may have to change type to int (astype(int)) before merging
# remove percent in deaths
# remove unnamed column

data_df.head()
# Out:
#   State    County              City  \
# 0    MN  HENNEPIN       ROBBINSDALE
# 1    MN  HENNEPIN       MINNEAPOLIS
# 2    MN  HENNEPIN  SAINT LOUIS PARK
# 3    MN  HENNEPIN       MINNEAPOLIS
# 4    MN  HENNEPIN       MINNEAPOLIS
#
#                                             Hospital  \
# 0                      NORTH MEMORIAL MEDICAL CENTER
# 1                   HENNEPIN COUNTY MEDICAL CENTER 1
# 2                   PARK NICOLLET METHODIST HOSPITAL
# 3                       ABBOTT NORTHWESTERN HOSPITAL
# 4  UNIVERSITY OF MINNESOTA  MEDICAL CENTER, FAIRVIEW
#
#                                             Location Patient Rating  \
# 0  3300 OAKDALE NORTH\nROBBINSDALE, MN\n(45.01421...              3
# 1  701 PARK AVENUE\nMINNEAPOLIS, MN\n(44.97285, -...              2
# 2  6500 EXCELSIOR BLVD\nSAINT LOUIS PARK, MN\n(44...              3
# 3  800 EAST 28TH STREET\nMINNEAPOLIS, MN\n(44.951...              3
# 4  2450 RIVERSIDE AVENUE\nMINNEAPOLIS, MN\n(44.96...              3
#
#   Completed Surveys Survey Response Rate (%)  Unnamed: 0 Deaths Population  \
# 0               957                       26         NaN    NaN        NaN
# 1               694                       13         NaN    NaN        NaN
# 2              1199                       34         NaN    NaN        NaN
# 3               865                       35         NaN    NaN        NaN
# 4               515                       25         NaN    NaN        NaN
#
#   Crude Rate Age Adjusted Rate % of Total Deaths
# 0        NaN               NaN               NaN
# 1        NaN               NaN               NaN
# 2        NaN               NaN               NaN
# 3        NaN               NaN               NaN
# 4        NaN               NaN               NaN

# %%
#visualize relationships between county mortality rates, hospital count, hospital star rating, 
# hospitals per capita, using matplotlib (opt. seaborn, tableau plot on map)
