# %% [markdown]
# ### Visualizations
#
# 1. Does Population Size alone affect Hospital Patient Experience?
# 2. Does # of Survey Responders alone affect Hospital Patient Experience? (total completed surveys vs county avg rating, avg response rate vs county avg rating, avg completed survey vs county avg rating)
#
# --- hospital count per county

# %%
# import dependencies
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# read in final csv
data_df = pd.read_csv('Resources/final_cleaned_data.csv', index_col=0)

data_df.head()
# Out:
#   State    County              City  \
# 0    MN  HENNEPIN       ROBBINSDALE
# 1    MN  HENNEPIN       MINNEAPOLIS
# 2    MN  HENNEPIN  SAINT LOUIS PARK
# 3    MN  HENNEPIN       MINNEAPOLIS
# 4    MN  HENNEPIN       MINNEAPOLIS
#
#                                             Hospital  \
# 0                      NORTH MEMORIAL MEDICAL CENTER
# 1                   HENNEPIN COUNTY MEDICAL CENTER 1
# 2                   PARK NICOLLET METHODIST HOSPITAL
# 3                       ABBOTT NORTHWESTERN HOSPITAL
# 4  UNIVERSITY OF MINNESOTA  MEDICAL CENTER, FAIRVIEW
#
#                                             Location  Patient Rating  \
# 0  3300 OAKDALE NORTH\nROBBINSDALE, MN\n(45.01421...               3
# 1  701 PARK AVENUE\nMINNEAPOLIS, MN\n(44.97285, -...               2
# 2  6500 EXCELSIOR BLVD\nSAINT LOUIS PARK, MN\n(44...               3
# 3  800 EAST 28TH STREET\nMINNEAPOLIS, MN\n(44.951...               3
# 4  2450 RIVERSIDE AVENUE\nMINNEAPOLIS, MN\n(44.96...               3
#
#    Completed Surveys  Survey Response Rate (%)  Deaths  Population  \
# 0                957                        26    8557     1232483
# 1                694                        13    8557     1232483
# 2               1199                        34    8557     1232483
# 3                865                        35    8557     1232483
# 4                515                        25    8557     1232483
#
#    Crude Rate  Age Adjusted Rate  % of Total Deaths
# 0      694.29             634.22               0.31
# 1      694.29             634.22               0.31
# 2      694.29             634.22               0.31
# 3      694.29             634.22               0.31
# 4      694.29             634.22               0.31

# %%
# make county level df with average rating, total completed surveys, avg completed surveys, avg response rate, 
#population, crude rate, adj crude rate

# group by state and county
grouper = data_df.groupby(["State", "County"])

# get avg rating, survey, and response rate
rating = grouper[["Patient Rating", "Completed Surveys", "Survey Response Rate (%)"]].mean()
rating.reset_index(inplace=True)

# get total completed surveys
survey = grouper["Completed Surveys"].sum().to_frame()
survey.reset_index(inplace=True)

# get mortality and population data
mortality = grouper[["Population", "Crude Rate", "Age Adjusted Rate"]].mean()
mortality.reset_index(inplace=True)

#merge df
county_df = pd.merge(rating, survey, on=["State", "County"], how="inner")
county_df = county_df.rename(columns={"Patient Rating" : "Average Patient Rating", "Completed Surveys_x":"Average Completed Surveys", 
                                      "Survey Response Rate (%)": "Average Survey Response Rate (%)", "Completed Surveys_y":"Total Completed Surveys"})

county_df = pd.merge(county_df, mortality, on =["State", "County"], how="inner")

county_df.head()
# Out:
#   State   County  Average Patient Rating  Average Completed Surveys  \
# 0    AL  AUTAUGA                     4.0                      579.0
# 1    AL  BALDWIN                     4.0                      758.0
# 2    AL  BARBOUR                     3.0                      184.0
# 3    AL   BLOUNT                     4.0                      128.0
# 4    AL   BUTLER                     4.0                      158.0
#
#    Average Survey Response Rate (%)  Total Completed Surveys  Population  \
# 0                              25.0                      579       55416
# 1                              33.0                     2274      208563
# 2                              34.0                      184       25965
# 3                              29.0                      128       57704
# 4                              31.0                      158       19998
#
#    Crude Rate  Age Adjusted Rate
# 0      938.36             884.39
# 1      946.48             716.92
# 2      985.94             800.68
# 3     1207.89             989.37
# 4     1375.14            1014.00

# %%
county_df["Population (Hundred Thousands)"] = county_df["Population"] / 1000000
county_df.head()
# Out:
#   State   County  Average Patient Rating  Average Completed Surveys  \
# 0    AL  AUTAUGA                     4.0                      579.0
# 1    AL  BALDWIN                     4.0                      758.0
# 2    AL  BARBOUR                     3.0                      184.0
# 3    AL   BLOUNT                     4.0                      128.0
# 4    AL   BUTLER                     4.0                      158.0
#
#    Average Survey Response Rate (%)  Total Completed Surveys  Population  \
# 0                              25.0                      579       55416
# 1                              33.0                     2274      208563
# 2                              34.0                      184       25965
# 3                              29.0                      128       57704
# 4                              31.0                      158       19998
#
#    Crude Rate  Age Adjusted Rate  Population (Hundred Thousands)
# 0      938.36             884.39                        0.055416
# 1      946.48             716.92                        0.208563
# 2      985.94             800.68                        0.025965
# 3     1207.89             989.37                        0.057704
# 4     1375.14            1014.00                        0.019998

# %%
# export to csv
county_df.to_csv("Resources/county_data.csv")

# %%
# Does Population Size alone affect Hospital Patient Experience?
sns.regplot(x="Population (Hundred Thousands)", y="Average Patient Rating", data=county_df)
plt.title("Population vs. Average Patient Rating")
plt.ylim(0, 5.5)
plt.show()
None

# %%
# Does # of Survey Responders alone affect Hospital Patient Experience? 
# (total completed surveys vs county avg rating)

sns.regplot(x="Total Completed Surveys", y="Average Patient Rating", data=county_df)
plt.title("Total Completed Surveys vs. Average Patient Rating")
plt.ylim(0, 5.5)
plt.show()
None

# %%
# Does # of Survey Responders alone affect Hospital Patient Experience? 
# (avg response rate vs county avg rating)

sns.regplot(x="Average Survey Response Rate (%)", y="Average Patient Rating", data=county_df)
plt.title("Average Survey Response Rate (%) vs. Average Patient Rating")
plt.ylim(0, 5.5)
plt.show()
None

# %%
# Does # of Survey Responders alone affect Hospital Patient Experience? 
# (avg completed survey vs county avg rating)

sns.regplot(x="Average Completed Surveys", y="Average Patient Rating", data=county_df)
plt.title("Average Completed Surveys vs. Average Patient Rating")
plt.ylim(0, 5.5)
plt.show()
None
