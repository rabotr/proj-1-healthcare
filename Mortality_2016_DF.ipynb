# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Import patient survey data into pandas from CSV
mortality_df = pd.read_csv('Resources/Mortality_2016.csv')
mortality_df
# Out:
#                       County  County Code   Deaths Population Crude Rate  \
# 0         Autauga County, AL       1001.0      520      55416     938.36
# 1         Baldwin County, AL       1003.0     1974     208563     946.48
# 2         Barbour County, AL       1005.0      256      25965     985.94
# 3            Bibb County, AL       1007.0      239      22643    1055.51
# 4          Blount County, AL       1009.0      697      57704    1207.89
# 5         Bullock County, AL       1011.0      133      10362    1283.54
# 6          Butler County, AL       1013.0      275      19998    1375.14
# 7         Calhoun County, AL       1015.0     1404     114611    1225.01
# 8        Chambers County, AL       1017.0      460      33843    1359.22
# 9        Cherokee County, AL       1019.0      361      25725     1403.3
# 10        Chilton County, AL       1021.0      475      43941    1080.99
# 11        Choctaw County, AL       1023.0      180      12993    1385.36
# ...

# %%
mortality_df[["county", "state"]] = mortality_df['County'].str.split(',', expand=True)
del mortality_df['County Code']
mortality_df
# Out:
#                       County   Deaths Population Crude Rate  \
# 0         Autauga County, AL      520      55416     938.36
# 1         Baldwin County, AL     1974     208563     946.48
# 2         Barbour County, AL      256      25965     985.94
# 3            Bibb County, AL      239      22643    1055.51
# 4          Blount County, AL      697      57704    1207.89
# 5         Bullock County, AL      133      10362    1283.54
# 6          Butler County, AL      275      19998    1375.14
# 7         Calhoun County, AL     1404     114611    1225.01
# 8        Chambers County, AL      460      33843    1359.22
# 9        Cherokee County, AL      361      25725     1403.3
# 10        Chilton County, AL      475      43941    1080.99
# 11        Choctaw County, AL      180      12993    1385.36
# 12         Clarke County, AL      315      24392    1291.41
# 13           Clay County, AL      177      13492    1311.89
# 14       Cleburne County, AL      191      14924    1279.82
# ...

# %%
clean_mortality = mortality_df[["Deaths", "Population", "Crude Rate",
                           "Age Adjusted Rate", "% of Total Deaths", "county", "state"]]
clean_mortality
# Out:
#        Deaths Population Crude Rate Age Adjusted Rate % of Total Deaths  \
# 0         520      55416     938.36            884.39             0.02%
# 1        1974     208563     946.48            716.92             0.07%
# 2         256      25965     985.94            800.68             0.01%
# 3         239      22643    1055.51            927.67             0.01%
# 4         697      57704    1207.89            989.37             0.03%
# 5         133      10362    1283.54           1063.01             0.00%
# 6         275      19998    1375.14              1014             0.01%
# 7        1404     114611    1225.01           1023.86             0.05%
# 8         460      33843    1359.22           1015.77             0.02%
# 9         361      25725     1403.3           1022.32             0.01%
# 10        475      43941    1080.99            920.05             0.02%
# 11        180      12993    1385.36            978.95             0.01%
# ...
